# %% [markdown]
# <a href="https://colab.research.google.com/github/jamescp/Utils/blob/master/Regressao_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

dados_iris = load_iris()
dados_iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
type(dados_iris)
# Out:
# sklearn.utils.Bunch

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# %%
#df.rename(columns={0:'sepal_length', 1:'sepal_width', 2:'petal_length', 3:'petal_width', 4:'species'})

# %%
type(dados_iris)
# Out:
# sklearn.utils.Bunch

# %%
print(dados_iris["target_names"][0:5])
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
y = df.iloc[0:100, 4].values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-47b5224fdace> in <module>()
# ----> 1 y = df.iloc[0:100, 4].values
#
# NameError: name 'df' is not defined

# %%
x = df.iloc[0:100, 0:4]

# %%
import IPython
from IPython.display import YouTubeVideo, HTML, Image, display
Image('https://i.stack.imgur.com/ZE9k1.png')

# %%
#verificar especies
#df['Species'].value_counts()
